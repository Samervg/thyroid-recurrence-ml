# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing  import LabelEncoder, StandardScaler
from sklearn.metrics    import classification_report, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd

from tensorflow.keras.optimizers import Adam



df = pd.read_csv("thyroid_data.csv")
# Out:
# WARNING:tensorflow:From c:\Users\Acer\Desktop\thyroid_recurrence_ml\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


y = df["Recurred"].apply(lambda x: 1 if x == "Yes" else 0)


X = df.drop("Recurred", axis=1)
X = pd.get_dummies(X, drop_first=True)  #

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
mlp_model = Sequential()
mlp_model.add(Dense(64, activation='relu', input_dim=x_train.shape[1]))
mlp_model.add(Dropout(0.3))
mlp_model.add(Dense(1, activation='sigmoid'))

mlp_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

mlp_model.fit(x_train, y_train, epochs=50, batch_size=16, validation_split=0.1)    # mlp model egitimi

y_pred_mlp = (mlp_model.predict(x_test) > 0.5).astype("int32")

from sklearn.metrics import classification_report, accuracy_score
print("MLP Raporu:\n")
print(classification_report(y_test, y_pred_mlp))
print("Accuracy:", accuracy_score(y_test, y_pred_mlp))
# Out:
# WARNING:tensorflow:From c:\Users\Acer\Desktop\thyroid_recurrence_ml\tf-env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Acer\Desktop\thyroid_recurrence_ml\tf-env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Acer\Desktop\thyroid_recurrence_ml\tf-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Acer\Desktop\thyroid_recurrence_ml\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 18/18 [==============================] - 1s 17ms/step - loss: 0.7469 - accuracy: 0.5127 - val_loss: 0.4996 - val_accuracy: 0.8065
# Epoch 2/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5325 - accuracy: 0.7745 - val_loss: 0.3588 - val_accuracy: 0.9032
# Epoch 3/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3768 - accuracy: 0.8727 - val_loss: 0.2895 - val_accuracy: 0.9032
# Epoch 4/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3161 - accuracy: 0.8800 - val_loss: 0.2479 - val_accuracy: 0.9355
# Epoch 5/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2869 - accuracy: 0.8909 - val_loss: 0.2261 - val_accuracy: 0.9355
# Epoch 6/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.9236 - val_loss: 0.2116 - val_accuracy: 0.9355
# Epoch 7/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2099 - accuracy: 0.9309 - val_loss: 0.2012 - val_accuracy: 0.9355
# Epoch 8/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1842 - accuracy: 0.9382 - val_loss: 0.1976 - val_accuracy: 0.9355
# Epoch 9/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1854 - accuracy: 0.9418 - val_loss: 0.1936 - val_accuracy: 0.9677
# Epoch 10/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1614 - accuracy: 0.9455 - val_loss: 0.1930 - val_accuracy: 0.9677
# Epoch 11/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1606 - accuracy: 0.9418 - val_loss: 0.1950 - val_accuracy: 0.9677
# Epoch 12/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1472 - accuracy: 0.9600 - val_loss: 0.1957 - val_accuracy: 0.9677
# Epoch 13/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1530 - accuracy: 0.9309 - val_loss: 0.1965 - val_accuracy: 0.9355
# Epoch 14/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1283 - accuracy: 0.9600 - val_loss: 0.2001 - val_accuracy: 0.9355
# Epoch 15/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1135 - accuracy: 0.9636 - val_loss: 0.1989 - val_accuracy: 0.9355
# Epoch 16/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1180 - accuracy: 0.9673 - val_loss: 0.2019 - val_accuracy: 0.9355
# Epoch 17/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0912 - accuracy: 0.9782 - val_loss: 0.2056 - val_accuracy: 0.9355
# Epoch 18/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1013 - accuracy: 0.9782 - val_loss: 0.2078 - val_accuracy: 0.9355
# Epoch 19/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9709 - val_loss: 0.2107 - val_accuracy: 0.9355
# Epoch 20/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0858 - accuracy: 0.9745 - val_loss: 0.2134 - val_accuracy: 0.9355
# Epoch 21/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9818 - val_loss: 0.2156 - val_accuracy: 0.9355
# Epoch 22/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9782 - val_loss: 0.2179 - val_accuracy: 0.9355
# Epoch 23/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0790 - accuracy: 0.9818 - val_loss: 0.2230 - val_accuracy: 0.9355
# Epoch 24/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9709 - val_loss: 0.2287 - val_accuracy: 0.9355
# Epoch 25/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9709 - val_loss: 0.2304 - val_accuracy: 0.9355
# Epoch 26/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9745 - val_loss: 0.2346 - val_accuracy: 0.9355
# Epoch 27/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0516 - accuracy: 0.9927 - val_loss: 0.2361 - val_accuracy: 0.9355
# Epoch 28/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9891 - val_loss: 0.2420 - val_accuracy: 0.9355
# Epoch 29/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0594 - accuracy: 0.9818 - val_loss: 0.2437 - val_accuracy: 0.9355
# Epoch 30/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0489 - accuracy: 0.9855 - val_loss: 0.2464 - val_accuracy: 0.9032
# Epoch 31/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9745 - val_loss: 0.2548 - val_accuracy: 0.9032
# Epoch 32/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9818 - val_loss: 0.2584 - val_accuracy: 0.9032
# Epoch 33/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 0.9964 - val_loss: 0.2559 - val_accuracy: 0.9032
# Epoch 34/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0480 - accuracy: 0.9855 - val_loss: 0.2617 - val_accuracy: 0.9032
# Epoch 35/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9782 - val_loss: 0.2629 - val_accuracy: 0.9032
# Epoch 36/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0453 - accuracy: 0.9855 - val_loss: 0.2641 - val_accuracy: 0.9032
# Epoch 37/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9927 - val_loss: 0.2727 - val_accuracy: 0.9032
# Epoch 38/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 0.9818 - val_loss: 0.2827 - val_accuracy: 0.9032
# Epoch 39/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0386 - accuracy: 0.9855 - val_loss: 0.2844 - val_accuracy: 0.9032
# Epoch 40/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 0.9782 - val_loss: 0.2903 - val_accuracy: 0.9032
# Epoch 41/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.9891 - val_loss: 0.2844 - val_accuracy: 0.9032
# Epoch 42/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9927 - val_loss: 0.2940 - val_accuracy: 0.9032
# Epoch 43/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0295 - accuracy: 0.9891 - val_loss: 0.3001 - val_accuracy: 0.9032
# Epoch 44/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9855 - val_loss: 0.3009 - val_accuracy: 0.9032
# Epoch 45/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0331 - accuracy: 0.9927 - val_loss: 0.3062 - val_accuracy: 0.9032
# Epoch 46/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9964 - val_loss: 0.3139 - val_accuracy: 0.9032
# Epoch 47/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0323 - accuracy: 0.9964 - val_loss: 0.3155 - val_accuracy: 0.9032
# Epoch 48/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 0.9818 - val_loss: 0.3070 - val_accuracy: 0.9032
# Epoch 49/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9964 - val_loss: 0.3181 - val_accuracy: 0.9032
# Epoch 50/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9964 - val_loss: 0.3248 - val_accuracy: 0.9032
# 3/3 [==============================] - 0s 1ms/step
# MLP Raporu:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        58
#            1       0.95      0.95      0.95        19
#
#     accuracy                           0.97        77
#    macro avg       0.97      0.97      0.97        77
# weighted avg       0.97      0.97      0.97        77
#
# Accuracy: 0.974025974025974
